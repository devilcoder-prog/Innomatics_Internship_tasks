# %% [markdown]
# ### Problem 1: Unique Words in a Sentence

# %%
sentence = input("Enter sentence: ")
words = sentence.split()
unique_words = set(words)
print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence:  Hello i am i
# Unique words count: 3
# Unique words: {'am', 'i', 'Hello'}

# %% [markdown]
# ### Problem 2: Highest Salary from Employee Data

# %%
employees = {
    "Dilkhush": 7500,
    "Nikhil": 6000,
    "Ajay": 7000
}
highest_employee = max(employees, key=employees.get)
highest_salary = employees[highest_employee]
print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Dilkhush - 7500

# %% [markdown]
# ### Problem 3: Find Maximum and Minimum Values

# %%
numbers = [48, 25, 84, 15, 69]
maximum = numbers[0]
minimum = numbers[0]
for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num
print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)
# Out:
# List: [48, 25, 84, 15, 69]
# Max: 84
# Min: 15

# %% [markdown]
# ### Problem 4: Count Products Above a Price Threshold

# %%
prices = [470, 1200, 897, 500, 700]
count = 0
for price in prices:
    if price > 1000:
        count += 1
print("Products above 1000:", count)
# Out:
# Products above 1000: 1

# %% [markdown]
# ### Problem 5: Calculate Attendance Percentage

# %%
attendance = ["P", "P", "A", "A", "P"]
present_count = 0
for day in attendance:
    if day == "P":
        present_count += 1
total_days = len(attendance)
percentage = (present_count / total_days) * 100
print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 60.0

# %% [markdown]
# ### Problem 6: Remove Duplicate Phone Numbers

# %%
phone_numbers = [9876547840, 9723456789, 9876543210]
unique_numbers = set(phone_numbers)
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876547840, 9876543210, 9723456789}

# %% [markdown]
# ### Problem 7: Count Character Frequency

# %%
text = "cnodensation"
char_count = {}
for ch in text:
    if ch in char_count:
        char_count[ch] += 1
    else:
        char_count[ch] = 1
print(char_count)
# Out:
# {'c': 1, 'n': 3, 'o': 2, 'd': 1, 'e': 1, 's': 1, 'a': 1, 't': 1, 'i': 1}

# %% [markdown]
# ### Problem 8: Convert List to Tuple

# %%
numbers = [100, 200,300]
numbers_tuple = tuple(numbers)
print("Tuple:", numbers_tuple)
# Out:
# Tuple: (100, 200, 300)

# %% [markdown]
# ### Problem 9: Check if a Key Exists in a Dictionary

# %%
employees = {
    "Ram": 7000,
    "Anil": 6000,
    "Kirti": 4000
}
key_to_check = "Ravi"
if key_to_check in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee does not exist

# %% [markdown]
# ### Problem 10: Calculate Average Marks

# %%
marks = [60, 77, 85, 74]
total = sum(marks)
average = total / len(marks)
print("Average Marks:", average)
# Out:
# Average Marks: 74.0
